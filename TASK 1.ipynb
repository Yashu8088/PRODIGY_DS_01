# %%
pip install pandas matplotlib seaborn
# Out:
# ...
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Replace with your actual CSV file path
file_path = "C:\\Users\\yashu\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_20333.csv"

# %%
# Read the data, skipping the metadata rows
df = pd.read_csv(file_path, skiprows=4)

# %%
# Filter out regions, keep only actual countries
exclude_keywords = ['income', 'total', 'World', 'OECD', 'IDA', 'IBRD', 'demographic', 'East Asia', 'Sub-Saharan', 'Europe', 'Arab']
df_countries = df[~df['Country Name'].str.contains('|'.join(exclude_keywords), case=False, na=False)]

# %%
# Get top 10 most populous countries
data_2022 = df[['Country Name', '2022']]  # Adjust if needed
top_10 = data_2022.sort_values(by='2022', ascending=False).head(10)
print(top_10)
# Out:
#                    Country Name          2022
# 259                       World  7.990400e+09
# 103            IDA & IBRD total  6.795050e+09
# 140         Low & middle income  6.438272e+09
# 156               Middle income  5.846791e+09
# 102                   IBRD only  4.928522e+09
# 62   Early-demographic dividend  3.470645e+09
# 139         Lower middle income  3.043358e+09
# 249         Upper middle income  2.803432e+09
# 63          East Asia & Pacific  2.379648e+09
# 142   Late-demographic dividend  2.324126e+09

# %%
# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(top_10['Country Name'], top_10['2022'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Most Populated Countries in 2022')
plt.xlabel('Country')
plt.ylabel('Population')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
